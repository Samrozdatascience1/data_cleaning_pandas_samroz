# %%
import pandas as pd
df=pd.read_csv("G:\/police.csv")
df
# Out:
#         stop_date stop_time  county_name driver_gender  driver_age_raw  \
# 0      2005-01-02     01:55          NaN             M          1985.0
# 1      2005-01-18     08:15          NaN             M          1965.0
# 2      2005-01-23     23:15          NaN             M          1972.0
# 3      2005-02-20     17:15          NaN             M          1986.0
# 4      2005-03-14     10:00          NaN             F          1984.0
# ...           ...       ...          ...           ...             ...
# 91736  2015-12-31     20:27          NaN             M          1986.0
# 91737  2015-12-31     20:35          NaN             F          1982.0
# 91738  2015-12-31     20:45          NaN             M          1992.0
# 91739  2015-12-31     21:42          NaN             M          1993.0
# 91740  2015-12-31     22:46          NaN             M          1959.0
#
#        driver_age driver_race                   violation_raw  \
# ...

# %%
df.head()
# Out:
#     stop_date stop_time  county_name driver_gender  driver_age_raw  \
# 0  2005-01-02     01:55          NaN             M          1985.0
# 1  2005-01-18     08:15          NaN             M          1965.0
# 2  2005-01-23     23:15          NaN             M          1972.0
# 3  2005-02-20     17:15          NaN             M          1986.0
# 4  2005-03-14     10:00          NaN             F          1984.0
#
#    driver_age driver_race     violation_raw violation  search_conducted  \
# 0        20.0       White          Speeding  Speeding             False
# 1        40.0       White          Speeding  Speeding             False
# 2        33.0       White          Speeding  Speeding             False
# 3        19.0       White  Call for Service     Other             False
# 4        21.0       White          Speeding  Speeding             False
#
#   search_type   stop_outcome is_arrested stop_duration  drugs_related_stop
# ...

# %%
#There are some NAN values lets check them

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# county_name           91741
# search_type           88545
# driver_age             5621
# driver_gender          5335
# driver_race            5333
# violation_raw          5333
# violation              5333
# stop_outcome           5333
# is_arrested            5333
# stop_duration          5333
# driver_age_raw         5327
# stop_date                 0
# stop_time                 0
# search_conducted          0
# drugs_related_stop        0
# dtype: int64

# %%
#some coloumns have null values lets check their percentage and remove those coloums which have more than 25 percent of null values

# %%
df.isnull().sum().sort_values(ascending=False)/len(df)*100
# Out:
# county_name           100.000000
# search_type            96.516280
# driver_age              6.127032
# driver_gender           5.815284
# driver_race             5.813104
# violation_raw           5.813104
# violation               5.813104
# stop_outcome            5.813104
# is_arrested             5.813104
# stop_duration           5.813104
# driver_age_raw          5.806564
# stop_date               0.000000
# stop_time               0.000000
# search_conducted        0.000000
# drugs_related_stop      0.000000
# dtype: float64

# %%
#we saw that coloumns i.e country_name and search_type have missing values more than 25 percent so we will remove them bcz we cannot predict their values.

# %%
drop_data=df.isnull().sum().sort_values(ascending=False).head(2).index.values
data
# Out:
# county_name    91741
# search_type    88545
# dtype: int64

# %%
data=df.drop(drop_data,axis="columns")
data
# Out:
#         stop_date stop_time driver_gender  driver_age_raw  driver_age  \
# 0      2005-01-02     01:55             M          1985.0        20.0
# 1      2005-01-18     08:15             M          1965.0        40.0
# 2      2005-01-23     23:15             M          1972.0        33.0
# 3      2005-02-20     17:15             M          1986.0        19.0
# 4      2005-03-14     10:00             F          1984.0        21.0
# ...           ...       ...           ...             ...         ...
# 91736  2015-12-31     20:27             M          1986.0        29.0
# 91737  2015-12-31     20:35             F          1982.0        33.0
# 91738  2015-12-31     20:45             M          1992.0        23.0
# 91739  2015-12-31     21:42             M          1993.0        22.0
# 91740  2015-12-31     22:46             M          1959.0        56.0
#
#       driver_race                   violation_raw         violation  \
# ...

# %%
#Two columns with the most missing values has removed

# %%
data.isnull().sum().sort_values(ascending=False)/len(data)*100
# Out:
# driver_age            6.127032
# driver_gender         5.815284
# driver_race           5.813104
# violation_raw         5.813104
# violation             5.813104
# stop_outcome          5.813104
# is_arrested           5.813104
# stop_duration         5.813104
# driver_age_raw        5.806564
# stop_date             0.000000
# stop_time             0.000000
# search_conducted      0.000000
# drugs_related_stop    0.000000
# dtype: float64

# %%
#now we cannot remove these columns.Now we keep those rows with missing values less than 5

# %%
data=data[data.isnull().sum(axis=1)<5]
data
# Out:
#         stop_date stop_time driver_gender  driver_age_raw  driver_age  \
# 0      2005-01-02     01:55             M          1985.0        20.0
# 1      2005-01-18     08:15             M          1965.0        40.0
# 2      2005-01-23     23:15             M          1972.0        33.0
# 3      2005-02-20     17:15             M          1986.0        19.0
# 4      2005-03-14     10:00             F          1984.0        21.0
# ...           ...       ...           ...             ...         ...
# 91736  2015-12-31     20:27             M          1986.0        29.0
# 91737  2015-12-31     20:35             F          1982.0        33.0
# 91738  2015-12-31     20:45             M          1992.0        23.0
# 91739  2015-12-31     21:42             M          1993.0        22.0
# 91740  2015-12-31     22:46             M          1959.0        56.0
#
#       driver_race                   violation_raw         violation  \
# ...

# %%
data.isnull().sum().sort_values(ascending=False)/len(data)*100
# Out:
# driver_age            0.339089
# driver_gender         0.002315
# driver_age_raw        0.001157
# stop_date             0.000000
# stop_time             0.000000
# driver_race           0.000000
# violation_raw         0.000000
# violation             0.000000
# search_conducted      0.000000
# stop_outcome          0.000000
# is_arrested           0.000000
# stop_duration         0.000000
# drugs_related_stop    0.000000
# dtype: float64

# %%
data=data[data["driver_gender"].notnull()]
data
# Out:
#         stop_date stop_time driver_gender  driver_age_raw  driver_age  \
# 0      2005-01-02     01:55             M          1985.0        20.0
# 1      2005-01-18     08:15             M          1965.0        40.0
# 2      2005-01-23     23:15             M          1972.0        33.0
# 3      2005-02-20     17:15             M          1986.0        19.0
# 4      2005-03-14     10:00             F          1984.0        21.0
# ...           ...       ...           ...             ...         ...
# 91736  2015-12-31     20:27             M          1986.0        29.0
# 91737  2015-12-31     20:35             F          1982.0        33.0
# 91738  2015-12-31     20:45             M          1992.0        23.0
# 91739  2015-12-31     21:42             M          1993.0        22.0
# 91740  2015-12-31     22:46             M          1959.0        56.0
#
#       driver_race                   violation_raw         violation  \
# ...

# %%
data["driver_age"].describe()
# Out:
# count    86113.000000
# mean        34.011868
# std         12.738786
# min         15.000000
# 25%         23.000000
# 50%         31.000000
# 75%         43.000000
# max         99.000000
# Name: driver_age, dtype: float64

# %%
data=data[data["driver_age"].notnull()]
data
# Out:
#         stop_date stop_time driver_gender  driver_age_raw  driver_age  \
# 0      2005-01-02     01:55             M          1985.0        20.0
# 1      2005-01-18     08:15             M          1965.0        40.0
# 2      2005-01-23     23:15             M          1972.0        33.0
# 3      2005-02-20     17:15             M          1986.0        19.0
# 4      2005-03-14     10:00             F          1984.0        21.0
# ...           ...       ...           ...             ...         ...
# 91736  2015-12-31     20:27             M          1986.0        29.0
# 91737  2015-12-31     20:35             F          1982.0        33.0
# 91738  2015-12-31     20:45             M          1992.0        23.0
# 91739  2015-12-31     21:42             M          1993.0        22.0
# 91740  2015-12-31     22:46             M          1959.0        56.0
#
#       driver_race                   violation_raw         violation  \
# ...

# %%
data.isnull().sum().sort_values(ascending=False)/len(data)*100
# Out:
# stop_date             0.0
# stop_time             0.0
# driver_gender         0.0
# driver_age_raw        0.0
# driver_age            0.0
# driver_race           0.0
# violation_raw         0.0
# violation             0.0
# search_conducted      0.0
# stop_outcome          0.0
# is_arrested           0.0
# stop_duration         0.0
# drugs_related_stop    0.0
# dtype: float64

# %%
#now our data is totally clean and we can use it furthur
